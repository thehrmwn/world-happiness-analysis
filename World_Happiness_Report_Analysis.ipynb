# %% [markdown]
# # **🗺️ World Happiness Report Analysis 😀**

# %% [markdown]
# ## 👋 **Introduction**

# %% [markdown]
# 🔎 **Context**
#
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.

# %% [markdown]
# 📑 **Content**
#
# The happiness scores and rankings use data from the Gallup World Poll. The scores are based on answers to the main life evaluation address inquired within the survey. This address, known as the Cantril ladder, asks respondents to think of a ladder with the best possible life for them being a 10 and the worst possible life being a 0 and to rate their own current lives on that scale. The scores are from nationally representative samples for the years 2013-2016 and use the Gallup weights to make the estimates representative. The columns following the happiness score estimate the extent to which each of six factors – economic production, social support, life expectancy, freedom, absence of corruption, and generosity – contribute to making life evaluations higher in each country than they are in Dystopia, a hypothetical country that has values equal to the world’s lowest national averages for each of the six factors. They have no impact on the total score reported for each country, but they do explain why some countries rank higher than others.
#
# The Happiness Score is a national average of the responses to the main life evaluation question asked in the Gallup World Poll (GWP), which uses the Cantril Ladder.

# %% [markdown]
# 💨 **About the Dataset** (*that will i use*)
#
# - **GDP per capita** ➡ measure of a country's economic output that accounts for its number of people
# - **Healthy Life Expectancy** ➡ the average number of years that a newborn can expect to live in "full health"—in other words, not hampered by disabling illnesses or injuries.
# - **Social support** ➡ having friends and other people, including family, to turn to in times of need or crisis to give you a broader focus and positive self-image. Social support enhances quality of life and provides a buffer against adverse life events.
# - **Freedom to make life choices** ➡ an individual's opportunity and autonomy to perform an action selected from at least two available options, unconstrained by external parties
# - **Generosity** ➡ the quality of being kind and generous.
# - **Corruption Perception** ➡ The Corruption Perceptions Index (CPI) is an index published annually by Transparency International since 1995 which ranks countries "by their perceived levels of public sector corruption, as determined by expert assessments and opinion surveys. The scale from 100 (very clean) to 0 (highly corrupt) [CPI source](https://en.wikipedia.org/wiki/Corruption_Perceptions_Index)

# %% [markdown]
# 🌍 **Source** of the datasets and information:
# 1. [World Happiness Report](https://www.kaggle.com/datasets/unsdsn/world-happiness) by SDSN
# 2. [World Happiness Report up to 2022](https://www.kaggle.com/datasets/mathurinache/world-happiness-report) by Mathurin AchÉ

# %% [markdown]
# ## **📈 Let's Start to Analyze**

# %% [markdown]
# Import the necessary Libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')

# %% [markdown]
# Import Dataset ( ℹ - *I will try to analyze World Happiness in 2022*

# %%
data = pd.read_csv('data/2022.csv')

# %% [markdown]
# ### 🧹**Data Cleaning and Formating**
#
# This step is part of Process step in 6 Steps of Data Analysis. It means, we will try to clean the dataset to make it ready to use, also change the formatting of the dataset if need it.
#
# So let's find out together!!

# %%
data
# Out:
#      RANK      Country Happiness score Whisker-high Whisker-low  \
# 0       1      Finland           7,821        7,886       7,756
# 1       2      Denmark           7,636        7,710       7,563
# 2       3      Iceland           7,557        7,651       7,464
# 3       4  Switzerland           7,512        7,586       7,437
# 4       5  Netherlands           7,415        7,471       7,359
# ..    ...          ...             ...          ...         ...
# 142   143      Rwanda*           3,268        3,462       3,074
# 143   144     Zimbabwe           2,995        3,110       2,880
# 144   145      Lebanon           2,955        3,049       2,862
# 145   146  Afghanistan           2,404        2,469       2,339
# 146   147           xx             NaN          NaN         NaN
#
#     Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                        2,518                        1,892
# 1                        2,226                        1,953
# ...

# %% [markdown]
# In 2022, there 147 data. But, as we can see in **row-147** the data is missing and also it looks useless so we can delete it. My guess is there may be an error during input or it may have been input by mistake.

# %%
data = data.drop([146])

# %%
data.shape
# Out:
# (146, 12)

# %%
data.columns
# Out:
# Index(['RANK', 'Country', 'Happiness score', 'Whisker-high', 'Whisker-low',
#        'Dystopia (1.83) + residual', 'Explained by: GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption'],
#       dtype='object')

# %% [markdown]
# From list of columns above. There are a lot of column, but I will not use all of the columns. I will remove some columns such as: *Whisker-high, Whisker-low, and Dystopia*. Also, we can say that the name of those columns are hard to understand (for me), it will be good if we change the name of the column to make it more specific.

# %%
#Drop the columns
data.drop(columns=['Whisker-high', 'Whisker-low', 'Dystopia (1.83) + residual'], inplace=True)

# %%
#Rename columns
data.rename(columns={'Explained by: GDP per capita': 'GDP',
                     'Explained by: Social support': 'Social Support',
                     'Explained by: Healthy life expectancy': 'Healthy Life',
                     'Explained by: Freedom to make life choices': 'Freedom',
                     'Explained by: Generosity': 'Generosity',
                     'Explained by: Perceptions of corruption': 'Perceptions of Corruption',},
            inplace = True)

data.columns
# Out:
# Index(['RANK', 'Country', 'Happiness score', 'GDP', 'Social Support',
#        'Healthy Life', 'Freedom', 'Generosity', 'Perceptions of Corruption'],
#       dtype='object')

# %% [markdown]
# After we drop the column, and also change the name of the column. List columns yang akan kita gunakan diantaranya: *Rank, Country, Happiness score, GDP, Social Support, Healthy Life, Freedom, Generosity, and Perceptions of Corruption*

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   RANK                       146 non-null    int64
#  1   Country                    146 non-null    object
#  2   Happiness score            146 non-null    object
#  3   GDP                        146 non-null    object
#  4   Social Support             146 non-null    object
#  5   Healthy Life               146 non-null    object
#  6   Freedom                    146 non-null    object
#  7   Generosity                 146 non-null    object
#  8   Perceptions of Corruption  146 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 10.4+ KB

# %% [markdown]
# **Oh NO!**. Look at the datatype, it shows most of our columns is *object* (it's incompatible datatype - also it's wrong). So, We Need to convert it to compatible datatype and that is *float*, as we know the data is decimal also.

# %%
columns_convert = ['Happiness score', 'GDP', 'Social Support', 'Healthy Life', 'Freedom', 'Generosity', 'Perceptions of Corruption']

for col_name in columns_convert:
    data[col_name] = data[col_name].str.replace(',', '.')
    data[col_name] = data[col_name].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   RANK                       146 non-null    int64
#  1   Country                    146 non-null    object
#  2   Happiness score            146 non-null    float64
#  3   GDP                        146 non-null    float64
#  4   Social Support             146 non-null    float64
#  5   Healthy Life               146 non-null    float64
#  6   Freedom                    146 non-null    float64
#  7   Generosity                 146 non-null    float64
#  8   Perceptions of Corruption  146 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 10.4+ KB

# %% [markdown]
# **YASH!!**. There you go. We have a compatible datatype

# %%
data.head()
# Out:
#    RANK      Country  Happiness score    GDP  Social Support  Healthy Life  \
# 0     1      Finland            7.821  1.892           1.258         0.775
# 1     2      Denmark            7.636  1.953           1.243         0.777
# 2     3      Iceland            7.557  1.936           1.320         0.803
# 3     4  Switzerland            7.512  2.026           1.226         0.822
# 4     5  Netherlands            7.415  1.945           1.206         0.787
#
#    Freedom  Generosity  Perceptions of Corruption
# 0    0.736       0.109                      0.534
# 1    0.719       0.188                      0.532
# 2    0.718       0.270                      0.191
# 3    0.677       0.147                      0.461
# 4    0.651       0.271                      0.419

# %% [markdown]
# Let's check if there are any Null Values in the data.

# %%
data.isnull().sum()
# Out:
# RANK                         0
# Country                      0
# Happiness score              0
# GDP                          0
# Social Support               0
# Healthy Life                 0
# Freedom                      0
# Generosity                   0
# Perceptions of Corruption    0
# dtype: int64

# %% [markdown]
# Also check if there are any Duplicated Values in the data (it will not happen, btw hhahaa).

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# As we know, there are no Null or Duplicate Values. So we can relax for a little bit, because our data have clean enough and ready to use for analyze.

# %%
data.describe()
# Out:
#              RANK  Happiness score         GDP  Social Support  Healthy Life  \
# count  146.000000       146.000000  146.000000      146.000000    146.000000
# mean    73.500000         5.553575    1.410445        0.905863      0.586171
# std     42.290661         1.086843    0.421663        0.280122      0.176336
# min      1.000000         2.404000    0.000000        0.000000      0.000000
# 25%     37.250000         4.888750    1.095500        0.732000      0.463250
# 50%     73.500000         5.568500    1.445500        0.957500      0.621500
# 75%    109.750000         6.305000    1.784750        1.114250      0.719750
# max    146.000000         7.821000    2.209000        1.320000      0.942000
#
#           Freedom  Generosity  Perceptions of Corruption
# count  146.000000  146.000000                 146.000000
# mean     0.517226    0.147377                   0.154781
# std      0.145859    0.082799                   0.127514
# ...

# %% [markdown]
# From above information, we can see the maximum and mean value for each variable/columns.

# %% [markdown]
# ### 🎖 **Exploratory Data Analysis**
#
# This step is part of Analyze. This section contains a basic statistical investigation of a given dataset. It is a crucial point in any analysis as it allows for a better understanding of the underlying data.
# - We will find the correlation between each variable (Happiness Score vs other)
# - trends from the data
# - Find deeper information (The Top 10 of something)

# %%
color_custome = sns.color_palette("ch:start=.2,rot=-.3", as_cmap=True)

# %%
sns.pairplot(data)

# %% [markdown]
# From above it show the correlation between each variable. From this plot actually we can get the conclusion directly. But it will not fun if we guest directly without further analyze.
#
# So, yeah be patience!

# %%
plt.figure(figsize = (8, 5))
sns.heatmap(data.corr(), cmap=color_custome, annot=True)

plt.show()

# %%
data.corr(method="pearson", min_periods=20)["Happiness score"].abs().sort_values(ascending=False)
# Out:
# Happiness score              1.000000
# RANK                         0.980856
# Social Support               0.777889
# GDP                          0.763677
# Healthy Life                 0.740260
# Freedom                      0.624822
# Perceptions of Corruption    0.416216
# Generosity                   0.063785
# Name: Happiness score, dtype: float64

# %% [markdown]
# Info: **The Pearson** method is the most common correlation method to use for numerical variables; it assigns a value between − 1 and 1, where 0 is no correlation, 1 is total positive correlation, and − 1 is total negative correlation.

# %% [markdown]
# The result of Heatmap and Correlation above it show the correlation positive between each varible.
#
# If we just use the Happiness Score as our main varible, it show that **Social Support is the highest correlation score**, followed by GDP, Healthy Life, Freedom, Perceptions of Corruption, and Generosity.
#
# From here, i will not use Generosity as a variable that we need to analyze deeper. (maybe you guys want to, it's ok. There's no Coercion here😀)

# %% [markdown]
# **Let's analyze Deeper**!

# %% [markdown]
# #### **Happiness Score**

# %% [markdown]
# Correlation between Happiness Score with other variables.

# %%
y_column = 'Happiness score'
x_columns = ['GDP', 'Social Support', 'Healthy Life', 'Freedom', 'Generosity', 'Perceptions of Corruption']
fig, axes = plt.subplots(2, 3, figsize=(12, 10))
axes = axes.flatten()

for i, x_col in enumerate(x_columns):
    ax = axes[i]
    ax.scatter(y = data['Happiness score'], x = data[x_col], alpha=0.5)
    ax.set_title(f'Happiness vs {x_col}', fontsize=14)
    ax.set_xlabel(x_col, fontsize=12)
    ax.set_ylabel(y_column, fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# It shows that, every variable has correlation with Happiness Score:
# 1. Variable GDP, Social Support, Healthy Life, and Freedom. **the higher the variable is in a country, the higher the country's happiness level.**
# 2. Generosity is not to much affect of Happiness Level, because sometimes **a country that has average happiness level more Generous than a country that have higher levels of happines**s.
# 3. Perceptions of Corruption. It will affect the Happiness Level of a country. **The higher the PCI value of a country, the more people will trust the government**. And vice-versa.

# %% [markdown]
# ❗❗ **Important**
#
# **Corruption**. the abuse of public power for private gain, is economic and social poison. Corruption undermines economic development for countries, regions, and firms, drives away foreign direct investment, and leads to poor infrastructure. Moving away from the economic consequences, corruption kills trust and support for democratic institutions and is, as the Biden administration recently acknowledged, a threat to national and global security.

# %% [markdown]
# **Top 10 Contries with Highest Happiness Score.**

# %%
ax = sns.barplot(x='Happiness score', y='Country', data=data.nlargest(10, 'Happiness score'),
            palette = sns.color_palette("dark:#79C", 10))

for label in ax.containers:
    ax.bar_label(label, fontsize=7)
plt.xlabel('Happiness', fontsize=12);
plt.ylabel('Country', fontsize=12);
plt.title("Top 10 Countries with Highest Happiness Score", fontsize=14)
plt.show()

# %% [markdown]
# **Congratulation Finland!** 🇫

# %% [markdown]
# #### **GDP**

# %% [markdown]
# We have already compared between Happiness Score and GDP. But what about GDP with other variable. Let's found out!!

# %%
y_column = 'GDP'
x_columns = ['Social Support', 'Healthy Life', 'Freedom', 'Perceptions of Corruption']
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

for i, x_col in enumerate(x_columns):
    ax = axes[i]
    ax.scatter(x = data[x_col], y=data['GDP'], alpha=0.5)
    ax.set_title(f'GDP vs {x_col}', fontsize=14)
    ax.set_xlabel(x_col, fontsize=12)
    ax.set_ylabel(y_column, fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# For GDP we found that:
# 1. Varible Social Support, Healthy Life, and Freedom. **the higher the variable is in a country, the higher the country's GDP**. It shows, the country has a special support from family or friend maybe, having a healthy life, and freedom.
# 2. For Perception of Corruption. Most of the data, that shows **the higher GDP is in a Country, sometimes make the perception of corruption higher.**

# %% [markdown]
# **Top 10 Contries with Highest GDP Score.**

# %%
ax = sns.barplot(x='GDP', y='Country', data=data.nlargest(10, 'GDP'),
            palette = sns.color_palette("dark:#79C", 10))

for label in ax.containers:
    ax.bar_label(label, fontsize=7)
plt.xlabel('GDP', fontsize=12);
plt.ylabel('Country', fontsize=12);
plt.title("Top 10 Countries with Highest GDP", fontsize=14)
plt.show()

# %% [markdown]
# **Congratulations Luxembourg!** 🇱

# %% [markdown]
# #### **Perceptions of Corruption**

# %%
y_column = 'Perceptions of Corruption'
x_columns = ['Social Support', 'Healthy Life', 'Freedom']
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
axes = axes.flatten()

for i, x_col in enumerate(x_columns):
    ax = axes[i]
    ax.scatter(x = data[x_col], y=data['Perceptions of Corruption'], alpha=0.5)
    ax.set_title(f'Perceptions vs {x_col}', fontsize=14)
    ax.set_xlabel(x_col, fontsize=12)
    ax.set_ylabel(y_column, fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# The distribution of the Perception of Corruption it shows similar for Social Support, Healthy Life, and Freedom. in **some cases the higher the variable value, the smaller the Perceptions**.

# %% [markdown]
# **Top 10 Contries with Highest Corruption Rate.**

# %%
ax = sns.barplot(x='Perceptions of Corruption', y='Country', data=data.nlargest(10, 'Perceptions of Corruption'),
            palette = sns.color_palette("dark:#79C", 10))

for label in ax.containers:
    ax.bar_label(label, fontsize=7)
plt.xlabel('Perceptions of Corruption', fontsize=12);
plt.ylabel('Country', fontsize=12);
plt.title("Top 10 Countries with Highest Perceptions of Corruption", fontsize=14)
plt.show()

# %% [markdown]
# **Congratulations Singapore!** 🇸

# %% [markdown]
# #### **Healthy Life**

# %%
y_column = 'Healthy Life'
x_columns = ['Social Support', 'Freedom']
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes = axes.flatten()

for i, x_col in enumerate(x_columns):
    ax = axes[i]
    ax.scatter(x = data[x_col], y=data['Healthy Life'], alpha=0.5)
    ax.set_title(f'Healthy Life vs {x_col}', fontsize=14)
    ax.set_xlabel(x_col, fontsize=12)
    ax.set_ylabel(y_column, fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# For Healthy Life vs Social Support and Freedom. It show that **the higher the value of healthy life, the higher the value of social support and freedom**. Most of the country has average Healthy Life arround **0.4 to 0.8**

# %% [markdown]
# **Top 10 Contries with Highest Healthy Life Score.**

# %%
ax = sns.barplot(x='Healthy Life', y='Country', data=data.nlargest(10, 'Healthy Life'),
            palette = sns.color_palette("dark:#79C", 10))

for label in ax.containers:
    ax.bar_label(label, fontsize=7)
plt.xlabel('Healthy Life', fontsize=12);
plt.ylabel('Country', fontsize=12);
plt.title("Top 10 Countries with Highest Healthy Life", fontsize=14)
plt.show()

# %% [markdown]
# **Congratulations Hongkong S.A.R. of China!** 🇭

# %% [markdown]
# #### **Freedom**

# %%
sns.scatterplot(data=data, x="Social Support", y="Freedom")
plt.title("Freedom vs Social Support", fontsize=15)
plt.show()

# %% [markdown]
# Between Freedom and Social Support, we can say **the average value of Freedom has the highest Social Support**.

# %% [markdown]
# **Top 10 Contries with Highest Freedom Score.**

# %%
ax = sns.barplot(x='Freedom', y='Country', data=data.nlargest(10, 'Freedom'),
            palette = sns.color_palette("dark:#79C", 10))

for label in ax.containers:
    ax.bar_label(label, fontsize=7)
plt.xlabel('Freedom', fontsize=12);
plt.ylabel('Country', fontsize=12);
plt.title("Top 10 Countries with Highest Freedom", fontsize=14)
plt.show()

# %% [markdown]
# **Congratulations Cambodia!** 🇰

# %% [markdown]
# #### **Social Support**

# %% [markdown]
# **Top 10 Contries with Highest Social Support.**

# %%
ax = sns.barplot(x='Social Support', y='Country', data=data.nlargest(10, 'Social Support'),
            palette = sns.color_palette("dark:#79C", 10))

for label in ax.containers:
    ax.bar_label(label, fontsize=7)
plt.xlabel('Social Support', fontsize=12);
plt.ylabel('Country', fontsize=12);
plt.title("Top 10 Countries with Highest Social Support", fontsize=14)
plt.show()

# %% [markdown]
# **Congratulations Iceland!** 🇮

# %% [markdown]
# #### **Generosity**

# %% [markdown]
# **Top 10 Contries with Highest Generosity Score.**

# %%
ax = sns.barplot(x='Generosity', y='Country', data=data.nlargest(10, 'Generosity'),
            palette = sns.color_palette("dark:#79C", 10))

for label in ax.containers:
    ax.bar_label(label, fontsize=7)
plt.xlabel('Generosity', fontsize=12);
plt.ylabel('Country', fontsize=12);
plt.title("Top 10 Countries with Highest Generosity", fontsize=14)
plt.show()

# %% [markdown]
# **Congratulations Indonesia!** 🇮 | (*my country, btw*)

# %% [markdown]
# ### 🆙 **Fully Concern**

# %% [markdown]
# In this section, i want to see the distribution between each variable using the data from previous years (2015 - 2022). Also we can **pay more attention** to **Social Support (Family), GDP, Healthy Life, and Freedom**. Because, we can say that **these variables will determine the level of happiness of a country**.

# %%
import plotly.express as px

geo_viz = px.choropleth(data,
                    locations='Country',
                    locationmode='country names',
                    color='Happiness score',
                    color_continuous_scale='RdYlGn',
                    hover_name='Country',  # Equivalent to text
                    hover_data={'Happiness score': ':.2f', 'GDP': True, 'Perceptions of Corruption':':.3f', 'RANK':True},
                    labels={'Happiness score': 'Happiness Score'},
                    title='Geographical Visualization of Happiness Score')

geo_viz.update_geos(projection_type='azimuthal equal area', showcoastlines=True)

geo_viz.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Historical Data**

# %%
d15 = pd.read_csv('data/2015.csv'); d19 = pd.read_csv('data/2019.csv')
d16 = pd.read_csv('data/2016.csv'); d20 = pd.read_csv('data/2020.csv')
d17 = pd.read_csv('data/2017.csv'); d21 = pd.read_csv('data/2021.csv')
d18 = pd.read_csv('data/2018.csv')

# %%
d15.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201

# %%
d16.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463

# %%
d17.head(2)
# Out:
#    Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0   Norway               1            7.537      7.594445     7.479556
# 1  Denmark               2            7.522      7.581728     7.462272
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707

# %%
d18.head(2)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340

# %%
d19.head(2)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410

# %%
d20.head(2)
# Out:
#    Overall Rank Country name Regional indicator  Ladder score  \
# 0             1      Finland     Western Europe        7.8087
# 1             2      Denmark     Western Europe        7.6456
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
#
#    Logged GDP per capita  Social support  Healthy life expectancy  ...  \
# 0              10.639267        0.954330                71.900825  ...
# 1              10.774001        0.955991                72.402504  ...
#
#    Generosity  Perceptions of corruption  Ladder score in Dystopia  \
# 0   -0.059482                   0.195445                  1.972317
# 1    0.066202                   0.168489                  1.972317
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                          1.285190                      1.499526
# ...

# %%
d21.head(2)
# Out:
#    Overall Rank Country name Regional indicator  Ladder score  \
# 0             1      Finland     Western Europe         7.842
# 1             2      Denmark     Western Europe         7.620
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
#
#    Logged GDP per capita  Social support  Healthy life expectancy  ...  \
# 0                 10.775           0.954                     72.0  ...
# 1                 10.933           0.954                     72.7  ...
#
#    Generosity  Perceptions of corruption  Ladder score in Dystopia  \
# 0      -0.098                      0.186                      2.43
# 1       0.030                      0.179                      2.43
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                             1.446                         1.106
# ...

# %% [markdown]
# **Trend Distribution**

# %%
plt.figure(figsize=(12,5))
sns.kdeplot(d15['Family'], color='#92C6FF')
sns.kdeplot(d16['Family'], color='#97F0AA')
sns.kdeplot(d17['Family'], color='#FF9F9A')
sns.kdeplot(d18['Social support'], color='orange')
sns.kdeplot(d19['Social support'], color='#D0BBFF')
sns.kdeplot(d20['Explained by: Social support'], color='#FFFEA3')
sns.kdeplot(d21['Explained by: Social support'], color='#B0E0E6')
sns.kdeplot(data['Social Support'], color='red')

plt.legend(title='Healthy', loc='upper right', labels=['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'])
plt.title('Health over the Years', size=20)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(d15['Economy (GDP per Capita)'], color='#92C6FF')
sns.kdeplot(d16['Economy (GDP per Capita)'], color='#97F0AA')
sns.kdeplot(d17['Economy..GDP.per.Capita.'], color='#FF9F9A')
sns.kdeplot(d18['GDP per capita'], color='orange')
sns.kdeplot(d19['GDP per capita'], color='#D0BBFF')
sns.kdeplot(d20['Explained by: Log GDP per capita'], color='#FFFEA3')
sns.kdeplot(d21['Explained by: Log GDP per capita'], color='#B0E0E6')
sns.kdeplot(data['GDP'], color='red')

plt.legend(title='Healthy', loc='upper right', labels=['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'])
plt.title('Health over the Years', size=20)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(d15['Health (Life Expectancy)'], color='#92C6FF')
sns.kdeplot(d16['Health (Life Expectancy)'], color='#97F0AA')
sns.kdeplot(d17['Health..Life.Expectancy.'], color='#FF9F9A')
sns.kdeplot(d18['Healthy life expectancy'], color='orange')
sns.kdeplot(d19['Healthy life expectancy'], color='#D0BBFF')
sns.kdeplot(d20['Explained by: Healthy life expectancy'], color='#FFFEA3')
sns.kdeplot(d21['Explained by: Healthy life expectancy'], color='#B0E0E6')
sns.kdeplot(data['Healthy Life'], color='red')

plt.legend(title='Healthy', loc='upper right', labels=['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'])
plt.title('Health over the Years', size=20)
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.kdeplot(d15['Freedom'], color='#92C6FF')
sns.kdeplot(d16['Freedom'], color='#97F0AA')
sns.kdeplot(d17['Freedom'], color='#FF9F9A')
sns.kdeplot(d18['Freedom to make life choices'], color='orange')
sns.kdeplot(d19['Freedom to make life choices'], color='#D0BBFF')
sns.kdeplot(d20['Explained by: Freedom to make life choices'], color='#FFFEA3')
sns.kdeplot(d21['Explained by: Freedom to make life choices'], color='#B0E0E6')
sns.kdeplot(data['Freedom'], color='red')

plt.legend(title='Healthy', loc='upper right', labels=['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'])
plt.title('Health over the Years', size=20)
plt.show()

# %% [markdown]
# Every single these variable have stagnant distribution from each years. Maybe slightly increasing or decreasing, but have the same distribution.

# %% [markdown]
# ## 📓 Conclusion

# %% [markdown]
# After did an analysis, find the correlation between the variables, find the trends of something, etc. we can draw a conclusion:
# 1. Social Support, GDP, Healthy Life, and Freedom, are the variables that most influences the high level of happiness of a country.
# 2. A country's level of Geneourisity does not determine a country's level of happiness. It will be good if the country has high level of happiness and also high level of Generous. It will make a better place for our world!
# 3. A country that has a high GDP value, can be said that the people in that country have enough support systems, a healthy life, and freedom of choice in their lives.
# 4. In some cases, a higher level of happiness does not guarantee a higher perception of corruption. Sometimes a country that has average level of happiness has higher perceptions of corruption.

# %% [markdown]
# So yeah, The conclusion will be two-way (agree or disagree). But that's fine, beside the goal is to analysis/find something interesting inside the data, my goal also is to learn and discuss. It would be an honor if there are constructive suggestions or input from you for future analysis.

# %% [markdown]
# ## 🇮 **Indonesia** (*optional*)
# Since Indonesia is my country, to answer my curiosity  i want to find the trends of Happiness Score and other variable of Indonesia from 2015 to 2022.

# %% [markdown]
# do cleaning and changing the formatting step, so it will have the same data and columns.

# %%
data_15 = d15[['Country', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Generosity', 'Trust (Government Corruption)']]
data_16 = d16[['Country', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Generosity', 'Trust (Government Corruption)']]
data_17 = d17[['Country', 'Happiness.Rank', 'Happiness.Score', 'Economy..GDP.per.Capita.', 'Family', 'Health..Life.Expectancy.', 'Freedom', 'Generosity', 'Trust..Government.Corruption.']]
data_18 = d18[['Country or region', 'Overall rank', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']]
data_19 = d19[['Country or region', 'Overall rank', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']]
data_20 = d20[['Country name', 'Overall Rank', 'Ladder score', 'Explained by: Log GDP per capita', 'Explained by: Social support', 'Explained by: Healthy life expectancy', 'Explained by: Freedom to make life choices', 'Explained by: Generosity', 'Explained by: Perceptions of corruption']]
data_21 = d21[['Country name', 'Overall Rank', 'Ladder score', 'Explained by: Log GDP per capita', 'Explained by: Social support', 'Explained by: Healthy life expectancy', 'Explained by: Freedom to make life choices', 'Explained by: Generosity', 'Explained by: Perceptions of corruption']]
data_22 = data.copy()

# %%
#2015
data_15.rename(columns={'Economy (GDP per Capita)':'GDP',
                        'Family':'Social Support',
                        'Health (Life Expectancy)':'Healthy Life',
                        'Trust (Government Corruption)':'Perceptions of Corruption'}, inplace = True)

#2016
data_16.rename(columns={'Economy (GDP per Capita)':'GDP',
                        'Family':'Social Support',
                        'Health (Life Expectancy)':'Healthy Life',
                        'Trust (Government Corruption)':'Perceptions of Corruption'}, inplace=True)

#2017
data_17.rename(columns={'Happiness.Rank':'Happiness Rank',
                        'Happiness.Score':'Happiness Score',
                        'Economy..GDP.per.Capita.':'GDP',
                        'Family':'Social Support',
                        'Health..Life.Expectancy.':'Healthy Life',
                        'Trust..Government.Corruption.':'Perceptions of Corruption'}, inplace=True)

#2018
data_18.rename(columns={'Country or region':'Country',
                        'Overall rank':'Happiness Rank',
                        'Score':'Happiness Score',
                        'GDP per capita':'GDP',
                        'Social support':'Social Support',
                        'Healthy life expectancy':'Healthy Life',
                        'Freedom to make life choices':'Freedom',
                        'Perceptions of corruption':'Perceptions of Corruption'}, inplace=True)

#2019
data_19.rename(columns={'Country or region':'Country',
                        'Overall rank':'Happiness Rank',
                        'Score':'Happiness Score',
                        'GDP per capita':'GDP',
                        'Social support':'Social Support',
                        'Healthy life expectancy':'Healthy Life',
                        'Freedom to make life choices':'Freedom',
                        'Perceptions of corruption':'Perceptions of Corruption'}, inplace=True)

#2020
data_20.rename(columns={'Country name':'Country',
                        'Overall Rank':'Happiness Rank',
                        'Ladder score':'Happiness Score',
                        'Explained by: Log GDP per capita':'GDP',
                        'Explained by: Social support':'Social Support',
                        'Explained by: Healthy life expectancy':'Healthy Life',
                        'Explained by: Freedom to make life choices':'Freedom',
                        'Explained by: Generosity':'Generosity',
                        'Explained by: Perceptions of corruption':'Perceptions of Corruption'}, inplace=True)

#2021
data_21.rename(columns={'Country name':'Country',
                        'Overall Rank':'Happiness Rank',
                        'Ladder score':'Happiness Score',
                        'Explained by: Log GDP per capita':'GDP',
                        'Explained by: Social support':'Social Support',
                        'Explained by: Healthy life expectancy':'Healthy Life',
                        'Explained by: Freedom to make life choices':'Freedom',
                        'Explained by: Generosity':'Generosity',
                        'Explained by: Perceptions of corruption':'Perceptions of Corruption'}, inplace=True)

#2022
data_22.rename(columns={'RANK':'Happiness Rank',
                        'Happiness score':'Happiness Score'}, inplace=True)

# %% [markdown]
# I just want to keep the same format of dataset for my own purpose.

# %%
data_15.to_csv(r'data_new/world_2015.csv', index=False, header=True)
data_16.to_csv(r'data_new/world_2016.csv', index=False, header=True)
data_17.to_csv(r'data_new/world_2017.csv', index=False, header=True)
data_18.to_csv(r'data_new/world_2018.csv', index=False, header=True)
data_19.to_csv(r'data_new/world_2019.csv', index=False, header=True)
data_20.to_csv(r'data_new/world_2020.csv', index=False, header=True)
data_21.to_csv(r'data_new/world_2021.csv', index=False, header=True)
data_22.to_csv(r'data_new/world_2022.csv', index=False, header=True)

# %%
data_15=data_15.set_index("Country"); data_16=data_16.set_index("Country"); data_17=data_17.set_index("Country")
data_18=data_18.set_index("Country"); data_19=data_19.set_index("Country"); data_20=data_20.set_index("Country")
data_21=data_21.set_index("Country"); data_22=data_22.set_index("Country")

# %% [markdown]
# Since it is about Indonesia.

# %%
indonesia_2015=data_15.loc[["Indonesia"]]; indonesia_2016=data_16.loc[["Indonesia"]]; indonesia_2017=data_17.loc[["Indonesia"]]
indonesia_2018=data_18.loc[["Indonesia"]]; indonesia_2019=data_19.loc[["Indonesia"]]; indonesia_2020=data_20.loc[["Indonesia"]]
indonesia_2021=data_21.loc[["Indonesia"]]; indonesia_2022=data_22.loc[["Indonesia"]]

# %%
indonesia_2015["year"] = 2015
indonesia_2016["year"] = 2016
indonesia_2017["year"] = 2017
indonesia_2018["year"] = 2018
indonesia_2019["year"] = 2019
indonesia_2020["year"] = 2020
indonesia_2021["year"] = 2021
indonesia_2022["year"] = 2022

data_indonesia = pd.concat([indonesia_2015, indonesia_2016, indonesia_2017, indonesia_2018,
                        indonesia_2019, indonesia_2020, indonesia_2021, indonesia_2022],
                        ignore_index=True, sort=False)

data_indonesia.sort_values(by="year")
# Out:
#    Happiness Rank  Happiness Score       GDP  Social Support  Healthy Life  \
# 0              74           5.3990  0.828270        1.087080      0.637930
# 1              79           5.3140  0.951040        0.876250      0.493740
# 2              81           5.2620  0.995539        1.274445      0.492346
# 3              96           5.0930  0.899000        1.215000      0.522000
# 4              92           5.1920  0.931000        1.203000      0.660000
# 5              84           5.2856  0.891721        1.154801      0.610437
# 6              82           5.3450  0.954000        0.786000      0.433000
# 7              87           5.2400  1.382000        0.883000      0.539000
#
#     Freedom  Generosity  Perceptions of Corruption  year
# 0  0.466110    0.515350                   0.000000  2015
# 1  0.392370    0.565210                   0.003220  2016
# 2  0.443323    0.611705                   0.015317  2017
# 3  0.538000    0.484000                   0.018000  2018
# ...

# %% [markdown]
# - **Indonesia Happiness Rank (2015-2022)**

# %%
ax = sns.lineplot(data=data_indonesia, x="year", y="Happiness Rank", color="#4682A9")

for x, y in zip(data_indonesia["year"], data_indonesia["Happiness Rank"]):
    plt.text(x, y, f'{y}', ha='center', fontsize=10, color='black')

ax.invert_yaxis()
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Ranking", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title("Indonesia Happiness Ranking (2015 - 2022)", fontsize=14)
plt.show()

# %% [markdown]
# It shows that in 2022, Indonesia has dropped in Happiness Ranking from **82 to 87**.

# %% [markdown]
# - **Indonesia GDP Rate (2015 - 2022)**

# %%
ax = sns.lineplot(data=data_indonesia, x="year", y="GDP", color="#4682A9")

for x, y in zip(data_indonesia["year"], data_indonesia["GDP"]):
    plt.text(x, y, f'{y:.3f}', ha='center', fontsize=10, color='black')

ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("GDP", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title("Indonesia GDP Rate (2015 - 2022)", fontsize=14)
plt.show()

# %% [markdown]
# **Wow!**. The GDP Rate in 2022 is the highest GDP then pervious years.

# %% [markdown]
# - **Indonesia Healthy Life Expectancy Rate (2015 - 2022)**

# %%
ax = sns.lineplot(data=data_indonesia, x="year", y="Healthy Life", color="#4682A9")

for x, y in zip(data_indonesia["year"], data_indonesia["Healthy Life"]):
    plt.text(x, y, f'{y:.3f}', ha='center', fontsize=10, color='black')

ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Healthy Life", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title("Indonesia Healthy Life Expectancy Rate (2015 - 2022)", fontsize=14)
plt.show()

# %% [markdown]
# For Healthy Life Expectancy, in 2022 increased from the previous year to **0.539**

# %% [markdown]
# - **Indonesia Freedom Rate (2015 - 2022)**

# %%
ax = sns.lineplot(data=data_indonesia, x="year", y="Freedom", color="#4682A9")

for x, y in zip(data_indonesia["year"], data_indonesia["Freedom"]):
    plt.text(x, y, f'{y:.3f}', ha='center', fontsize=10, color='black')

ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Freedom", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title("Indonesia Freedom Rate (2015 - 2022)", fontsize=14)
plt.show()

# %% [markdown]
# **Yashh!**. The Freedom Rate from the previous 5 years always increase. And it shows in 2022 is the highest rate then previous years.

# %% [markdown]
# - **Indonesia Generosity Rate (2015 - 2022)**

# %%
ax = sns.lineplot(data=data_indonesia, x="year", y="Generosity", color="#4682A9")

for x, y in zip(data_indonesia["year"], data_indonesia["Generosity"]):
    plt.text(x, y, f'{y:.3f}', ha='center', fontsize=10, color='black')

ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Ranking", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title("Indonesia Generosity Rate (2015 - 2022)", fontsize=14)
plt.show()

# %% [markdown]
# It is sad that in 2022, the Generosity Rate has decreased, but **in 2022 Indonesia is also the most generous country in the world**!

# %% [markdown]
# - **Indonesia Perceptions of Corruption (2015-2022)**

# %%
ax = sns.lineplot(data=data_indonesia, x="year", y="Perceptions of Corruption", color="#4682A9")

for x, y in zip(data_indonesia["year"], data_indonesia["Perceptions of Corruption"]):
    plt.text(x, y, f'{y:.3f}', ha='center', fontsize=10, color='black')

ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Perceptions of Corruption", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title("Indonesia Perceptions of Corruption (2015 - 2022)", fontsize=14)
plt.show()

# %% [markdown]
# From above, We can be grateful that the Perceptions of Corruption continues to increase, but corruption is still corruption. In fact, There are still many cases of corruption that occur in Indonesia.

# %% [markdown]
# ### 📓 Conclusion For Indonesian

# %% [markdown]
# Maybe it same with the Conclusion above, maybe it's some suggestion for Indonesian or Indonesian Government:
#
# 1. Our GDP has increases from year-on-year. But it can be much better, How?. One of them is related to **MSMEs**, the community and the government government needs to **pay more attention and support to MSME entrepreneurs**. In fact, MSME can be called the backbone of the Indonesian economy. Through MSMEs, it can open up wider employment opportunities, because the more people who get jobs, the Healthy Life factor, the community's Social Support will also increase. And this will greatly affect the level of happiness itself.
# 2. Improve the education and skills. Excellent human resources are people who have skills and can utilize these skills well.
# 3. Continue to improve regulations that are still not good enough.
# 4. Support each others!
